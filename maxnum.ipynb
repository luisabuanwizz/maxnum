# %% [markdown]
# <a href="https://colab.research.google.com/github/luisabuanwizz/maxnum/blob/main/maxnum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# asks user numbers
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
num3 = int(input("Enter last number: "))

if num1 > num2 and num1 > num3:
    print ("The largest number is ",num1)

if num2 > num1 and num2 > num3:
    print ("The largest number is ",num2)

if num3 > num1 and num3 > num2:
    print ("The largest number is ",num3)

if num1 == num2 == num3:
   print ("All numbers are equal!")
